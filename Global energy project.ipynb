# %%
import pandas as pd

# %%
import matplotlib.pylab as plt

# %%
energy = pd.read_csv('global_sustainable_energy.csv')

# %%
energy
# Out:
#            Entity  Year  Access to electricity (% of population)  \
# 0     Afghanistan  2000                                 1.613591
# 1     Afghanistan  2001                                 4.074574
# 2     Afghanistan  2002                                 9.409158
# 3     Afghanistan  2003                                14.738506
# 4     Afghanistan  2004                                20.064968
# ...           ...   ...                                      ...
# 3644     Zimbabwe  2016                                42.561730
# 3645     Zimbabwe  2017                                44.178635
# 3646     Zimbabwe  2018                                45.572647
# 3647     Zimbabwe  2019                                46.781475
# 3648     Zimbabwe  2020                                52.747670
#
#       Access to clean fuels for cooking  \
# 0                                   6.2
# 1                                   7.2
# 2                                   8.2
# ...

# %%
print(energy.head())
# Out:
#         Entity  Year  Access to electricity (% of population)  \
# 0  Afghanistan  2000                                 1.613591
# 1  Afghanistan  2001                                 4.074574
# 2  Afghanistan  2002                                 9.409158
# 3  Afghanistan  2003                                14.738506
# 4  Afghanistan  2004                                20.064968
#
#    Access to clean fuels for cooking  \
# 0                                6.2
# 1                                7.2
# 2                                8.2
# 3                                9.5
# 4                               10.9
#
#    Renewable-electricity-generating-capacity-per-capita  \
# 0                                               9.22
# 1                                               8.86
# 2                                               8.47
# 3                                               8.09
# 4                                               7.75
#
# ...

# %%
united_states = energy[(energy.Entity == 'United States')]
print(united_states)
# Out:
#              Entity  Year  Access to electricity (% of population)  \
# 3502  United States  2000                                    100.0
# 3503  United States  2001                                    100.0
# 3504  United States  2002                                    100.0
# 3505  United States  2003                                    100.0
# 3506  United States  2004                                    100.0
# 3507  United States  2005                                    100.0
# 3508  United States  2006                                    100.0
# 3509  United States  2007                                    100.0
# 3510  United States  2008                                    100.0
# 3511  United States  2009                                    100.0
# 3512  United States  2010                                    100.0
# 3513  United States  2011                                    100.0
# 3514  United States  2012                                    100.0
# ...

# %%
import matplotlib.pyplot as plt
import pandas as pd


plt.scatter(x=united_states['Year'], y=united_states['Electricity from renewables (TWh)'])
plt.xlabel('Year')
plt.ylabel('Renewable Energy (TWh)')
plt.title('United States Renewable Energy Over Years')
plt.grid(True) 
plt.show()

# %%
plt.scatter(x=united_states['Year'], y=united_states['Electricity from fossil fuels (TWh)'])
plt.xlabel('Year')
plt.ylabel('Fossil Fuels (TWh)')
plt.title('United States Fuels Over Years')
plt.grid(True) 
plt.show()
